# %%
"""
Week 1 - Day 7 - Final Summary
==============================
Consolidating entire Week 1 pipeline
and preparing handoff to Week 2
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append('../src')

from preprocessing import load_and_preprocess
from visualizations import (
    plot_failure_distribution,
    plot_sensor_boxplots,
    plot_correlation_heatmap
)

plt.style.use('seaborn-v0_8')

# Load full pipeline
X, y, feature_names, df = load_and_preprocess(
    '../data/ai4i2020.csv'
)

print(f"✅ Week 1 Final Pipeline Loaded!")
print(f"   Shape     : {df.shape}")
print(f"   Features  : {len(feature_names)}")
print(f"   Failures  : {y.sum()}")
print(f"   Fail Rate : {y.mean()*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 17
#      14 sys.path.append('../src')
#      16 from preprocessing import load_and_preprocess
# ---> 17 from visualizations import (
#      18     plot_failure_distribution,
#      19     plot_sensor_boxplots,
#      20     plot_correlation_heatmap
#      21 )
#      23 plt.style.use('seaborn-v0_8')
#      25 # Load full pipeline
#
# ImportError: cannot import name 'plot_sensor_boxplots' from 'visualizations' (x:\Infotact\Predictive-Maintenance-IOT\notebooks\../src\visualizations.py)
